# %% [markdown]
# <a href="https://colab.research.google.com/github/cooolbabu/GoogleGemini101/blob/main/Text-To-Speech/Google_Text_to_Speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: google auth code

from google.colab import auth
auth.authenticate_user(project_id='364136482180')

# %%
pip install --upgrade google-cloud-texttospeech

# %%
from google.cloud import texttospeech

 # Instantiates a client
client = texttospeech.TextToSpeechClient()

  # Set the text input to be synthesized
synthesis_input = texttospeech.SynthesisInput(text="Hi. This is awesome. I finally got, Google Text to Speech, to work in Colab notebook")

  # Build the voice request, select the language code ("en-US") and the ssml
  # voice gender ("neutral")
voice = texttospeech.VoiceSelectionParams(
      language_code="en-US", ssml_gender=texttospeech.SsmlVoiceGender.NEUTRAL
  )

  # Select the type of audio file you want returned
audio_config = texttospeech.AudioConfig(
      audio_encoding=texttospeech.AudioEncoding.MP3
  )

  # Perform the text-to-speech request on the text input with the selected
  # voice parameters and audio file type
response = client.synthesize_speech(
      input=synthesis_input, voice=voice, audio_config=audio_config
  )

  # The response's audio_content is binary.
with open("output.mp3", "wb") as out:
      # Write the response to the output file.
      out.write(response.audio_content)
      print('Audio content written to file "output.mp3"')
  # [END tts_quickstart]
# Out:
# Audio content written to file "output.mp3"

# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt

#audio_path = 'output.mp3'

#x, sr = librosa.load(audio_path)

# %%
ipd.Audio('output.mp3', autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install gTTS

# %% [markdown]
# Another way to perform the same function without Project-id. Project-id is needed in Enterprise environments, where security is essential. In case, security is not important we can use this.
#
# Also, we can select different voices. Need to figure this out. See the differences between these two methods.
#
# I am of the opinion that the former method will have more choices. But you have to pay for those services. gTTS is a generic free version.

# %%
from gtts import gTTS
from IPython.display import Audio
from IPython.display import display
for voice in ["Sachin"]:
    tts = gTTS(f"Hello {voice}")
    tts.save('1.wav')
    sound_file = '1.wav'

# %%
wn = Audio(sound_file, autoplay=True) ##
display(wn)##
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wn = Audio('output.mp3', autoplay=True) ##
display(wn)##
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
